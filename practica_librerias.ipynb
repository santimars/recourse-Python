# %%
from cgi import print_arguments
import pandas as pd
import csv as csv
import matplotlib as mlt
import numpy as np

'''
Para carga de datos y exploracion trabajaremos con el fichero 
csv 05_03_weather.csv, que se encuentra dentro de la carpeta correspondiente
en el proyecto Anaconda Jupyter. Para cargarlo procedemos de la siguiente manera:
'''

d = pd.read_csv('05_03_weather.csv')

print(d)
#para obtener su numero de filas:
# Número de filas
print(len(d))

# Para saber los indices de filas  y los encabezados de las columnas:
print(d.index)

print(d.columns)    
#Para obtener todos los valores:
print(d.values)
# Para obtener informacion general del DataFrame:

# Info general
d.info()
# Para acceder a las primera o las ultimas fils del DataFrame usaremos las funciones head() o tail():

# head y tail
d.head() # Primeras 5 filas 


# head y tail
d.head(10) # Primeras 10 filas 

# head y tail
d.tail() # Ultimas 5 filas 


# head y tail
d.tail(10) # Últimas 10 filas 

# Para hacer slicing al DataFrame y obtener los valoes de las filas ubicados entre 2 filas indicadas:

# Obtener 5 filas entre la 20 y 24
d[20:25]

# Para acceder a una columna en concreto:
# Acceder a una columna en particular del dataframe

print(d['Humidity'].head(10))

# para obtener el minimo, el maximo y el promedio de una columna

print(d['Humidity'].min())
print(d['Humidity'].max())
print(d['Humidity'].mean())

print(d['Humidity'][:1000].mean())# lo primero que hace es ir a la columna humedad luego filtra la 1000 lineas y lugo hace un promedio
print(d[:1000]['Humidity'].mean())


'''
y por ultimo, para el uso de condicionales (d[”columna”][”condicion”]),
donde se devuelven todos los valores de una “columna” que cumplan una “condicion”:
'''
"""
# Ordenacion y Seleccion de series
temps = d['Temperature (C)'].hist()
print(type(temps)) # como se ve, temps es una serie de panda
temps_ordenadas = temps.sort_values(ascending=False)
print(temps_ordenadas[:10])
# Mostrar la temperatura cuya humedad sea menor o igual que la media de humedades
"""
#Una forma de hacerlo
df_ordenado = d.sort_values(by=["Temperature (C)","Apparent Temperature (C)"],ascending=False)
print(df_ordenado)
print(df_ordenado[:10])


# Para obtener un histograma, la distribucion de los datos de una columna:

print(d['Temperature (C)'].hist())
print(d['Temperature (C)'].plot(kind="kde"))
# Out:
# /var/folders/xx/mgkqp0vd3zq3jqqg6bqk8hx00000gn/T/ipykernel_2382/4220795586.py:1: DeprecationWarning: 'cgi' is deprecated and slated for removal in Python 3.13
#   from cgi import print_arguments
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# 1             9.355556                  7.227778      0.86            14.2646
# 2             9.377778                  9.377778      0.89             3.9284
# 3             8.288889                  5.944444      0.83            14.1036
# 4             8.755556                  6.977778      0.83            11.0446
# ...                ...                       ...       ...                ...
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                       251.0          15.8263         0.0
# 1                       259.0          15.8263         0.0
# 2                       204.0          14.9569         0.0
# 3                       269.0          15.8263         0.0
# 4                       259.0          15.8263         0.0
# ...                       ...              ...         ...
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 0                   1015.13       Partly cloudy throughout the day.
# 1                   1015.63       Partly cloudy throughout the day.
# 2                   1015.94       Partly cloudy throughout the day.
# 3                   1016.41       Partly cloudy throughout the day.
# 4                   1016.51       Partly cloudy throughout the day.
# ...                     ...                                     ...
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.
#
# [96453 rows x 12 columns]
# 96453
# RangeIndex(start=0, stop=96453, step=1)
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')
# [['2006-04-01 00:00:00.000 +0200' 'Partly Cloudy' 'rain' ... 0.0 1015.13
#   'Partly cloudy throughout the day.']
#  ['2006-04-01 01:00:00.000 +0200' 'Partly Cloudy' 'rain' ... 0.0 1015.63
#   'Partly cloudy throughout the day.']
#  ['2006-04-01 02:00:00.000 +0200' 'Mostly Cloudy' 'rain' ... 0.0 1015.94
#   'Partly cloudy throughout the day.']
#  ...
#  ['2016-09-09 21:00:00.000 +0200' 'Partly Cloudy' 'rain' ... 0.0 1015.66
#   'Partly cloudy starting in the morning.']
#  ['2016-09-09 22:00:00.000 +0200' 'Partly Cloudy' 'rain' ... 0.0 1015.95
#   'Partly cloudy starting in the morning.']
#  ['2016-09-09 23:00:00.000 +0200' 'Partly Cloudy' 'rain' ... 0.0 1016.16
#   'Partly cloudy starting in the morning.']]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB
# 0    0.89
# 1    0.86
# 2    0.89
# 3    0.83
# 4    0.83
# 5    0.85
# 6    0.95
# 7    0.89
# 8    0.82
# 9    0.72
# Name: Humidity, dtype: float64
# 0.0
# 1.0
# 0.7348989663359355
# 0.73124
# 0.73124
#                       Formatted Date        Summary Precip Type  \
# 12759  2007-07-22 15:00:00.000 +0200          Clear        rain
# 12737  2007-07-21 17:00:00.000 +0200  Partly Cloudy        rain
# 12664  2007-07-19 16:00:00.000 +0200  Partly Cloudy        rain
# 12712  2007-07-20 16:00:00.000 +0200  Partly Cloudy        rain
# 12711  2007-07-20 15:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 55495  2012-02-09 07:00:00.000 +0100          Foggy        snow
# 55490  2012-02-09 02:00:00.000 +0100          Foggy        snow
# 55493  2012-02-09 05:00:00.000 +0100          Foggy        snow
# 55494  2012-02-09 06:00:00.000 +0100          Foggy        snow
# 54847  2012-02-10 07:00:00.000 +0100          Foggy        snow
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 12759        39.905556                 37.538889      0.13            23.5865
# 12737        39.588889                 37.600000      0.15            12.2038
# 12664        38.983333                 37.461111      0.18             8.9355
# 12712        38.983333                 36.800000      0.15            15.4077
# 12711        38.983333                 36.627778      0.14            12.7190
# ...                ...                       ...       ...                ...
# 55495       -20.783333                -20.783333      0.80             4.4275
# 55490       -21.111111                -21.111111      0.74             3.2200
# 55493       -21.111111                -21.111111      0.78             4.8300
# 55494       -21.111111                -21.111111      0.71             3.2200
# 54847       -21.822222                -21.822222      0.80             3.0751
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 12759                   250.0           9.9820         0.0
# 12737                   283.0          10.3523         0.0
# 12664                   175.0           9.9820         0.0
# 12712                   133.0           9.9820         0.0
# 12711                   167.0           9.9820         0.0
# ...                       ...              ...         ...
# 55495                   181.0           1.7871         0.0
# 55490                   200.0           1.9320         0.0
# 55493                   180.0           2.5760         0.0
# 55494                   190.0           1.9320         0.0
# 54847                   323.0           1.3685         0.0
#
#        Pressure (millibars)                                      Daily Summary
# 12759               1007.55           Partly cloudy starting in the afternoon.
# 12737               1010.24  Partly cloudy starting in the morning continui...
# 12664               1013.34           Partly cloudy starting in the afternoon.
# 12712               1011.93  Partly cloudy starting in the afternoon contin...
# 12711               1012.34  Partly cloudy starting in the afternoon contin...
# ...                     ...                                                ...
# 55495               1032.33                               Foggy until morning.
# 55490               1034.30                               Foggy until morning.
# 55493               1033.30                               Foggy until morning.
# 55494               1032.60                               Foggy until morning.
# 54847               1033.66  Foggy starting in the morning continuing until...
#
# [96453 rows x 12 columns]
#                       Formatted Date        Summary Precip Type  \
# 12759  2007-07-22 15:00:00.000 +0200          Clear        rain
# 12737  2007-07-21 17:00:00.000 +0200  Partly Cloudy        rain
# 12664  2007-07-19 16:00:00.000 +0200  Partly Cloudy        rain
# 12712  2007-07-20 16:00:00.000 +0200  Partly Cloudy        rain
# 12711  2007-07-20 15:00:00.000 +0200  Partly Cloudy        rain
# 12735  2007-07-21 15:00:00.000 +0200  Partly Cloudy        rain
# 53727  2012-08-24 15:00:00.000 +0200  Partly Cloudy        rain
# 12736  2007-07-21 16:00:00.000 +0200  Partly Cloudy        rain
# 53728  2012-08-24 16:00:00.000 +0200  Partly Cloudy        rain
# 12760  2007-07-22 16:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 12759        39.905556                 37.538889      0.13            23.5865
# 12737        39.588889                 37.600000      0.15            12.2038
# 12664        38.983333                 37.461111      0.18             8.9355
# 12712        38.983333                 36.800000      0.15            15.4077
# 12711        38.983333                 36.627778      0.14            12.7190
# 12735        38.866667                 37.950000      0.21            12.7512
# 53727        38.861111                 37.327778      0.18            17.3880
# 12736        38.844444                 37.994444      0.21             9.2414
# 53728        38.838889                 37.261111      0.18            12.9444
# 12760        38.838889                 36.705556      0.15            23.7475
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 12759                   250.0           9.9820         0.0
# 12737                   283.0          10.3523         0.0
# 12664                   175.0           9.9820         0.0
# 12712                   133.0           9.9820         0.0
# 12711                   167.0           9.9820         0.0
# 12735                   269.0           9.9820         0.0
# 53727                   232.0           9.9820         0.0
# 12736                   222.0           9.9820         0.0
# 53728                   250.0           9.9820         0.0
# 12760                   249.0           9.9820         0.0
#
#        Pressure (millibars)                                      Daily Summary
# 12759               1007.55           Partly cloudy starting in the afternoon.
# 12737               1010.24  Partly cloudy starting in the morning continui...
# 12664               1013.34           Partly cloudy starting in the afternoon.
# 12712               1011.93  Partly cloudy starting in the afternoon contin...
# 12711               1012.34  Partly cloudy starting in the afternoon contin...
# 12735               1011.00  Partly cloudy starting in the morning continui...
# 53727               1009.89  Partly cloudy starting in the morning continui...
# 12736               1010.50  Partly cloudy starting in the morning continui...
# 53728               1009.38  Partly cloudy starting in the morning continui...
# 12760               1007.26           Partly cloudy starting in the afternoon.
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %%
d[ (d["Summary"]== "Foggy") & (d["Precip Type"] =="snow" )]
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 1562   2006-12-13 02:00:00.000 +0100   Foggy        snow        -0.483333
# 1563   2006-12-13 03:00:00.000 +0100   Foggy        snow        -0.483333
# 1564   2006-12-13 04:00:00.000 +0100   Foggy        snow        -0.922222
# 1565   2006-12-13 05:00:00.000 +0100   Foggy        snow        -1.038889
# 1566   2006-12-13 06:00:00.000 +0100   Foggy        snow        -1.088889
# ...                              ...     ...         ...              ...
# 93003  2016-03-18 06:00:00.000 +0100   Foggy        snow        -0.133333
# 93265  2016-03-28 05:00:00.000 +0200   Foggy        snow        -0.783333
# 93266  2016-03-28 06:00:00.000 +0200   Foggy        snow        -1.111111
# 93267  2016-03-28 07:00:00.000 +0200   Foggy        snow        -1.044444
# 93506  2016-03-09 06:00:00.000 +0100   Foggy        snow        -0.027778
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1562                  -4.150000      1.00            11.0929
# 1563                  -4.061111      0.96            10.7387
# 1564                  -3.477778      1.00             7.0679
# 1565                  -4.400000      1.00             9.4990
# 1566                  -4.438889      1.00             9.4346
# ...                         ...       ...                ...
# 93003                 -0.133333      0.92             3.1234
# 93265                 -2.950000      0.99             6.1019
# 93266                 -1.111111      0.93             0.0000
# 93267                 -1.044444      1.00             0.0000
# 93506                 -2.705556      0.99             7.8568
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 1562                    219.0           0.4830         0.0
# 1563                    200.0           0.3220         0.0
# 1564                    206.0           0.1610         0.0
# 1565                    199.0           0.1610         0.0
# 1566                    219.0           0.3220         0.0
# ...                       ...              ...         ...
# 93003                   201.0           0.8855         0.0
# 93265                    91.0           3.1073         0.0
# 93266                     0.0           0.1610         0.0
# 93267                     0.0           0.7728         0.0
# 93506                   320.0           3.0107         0.0
#
#        Pressure (millibars)              Daily Summary
# 1562                1031.56  Foggy throughout the day.
# 1563                1031.47  Foggy throughout the day.
# 1564                1031.23  Foggy throughout the day.
# 1565                1031.41  Foggy throughout the day.
# 1566                1031.98  Foggy throughout the day.
# ...                     ...                        ...
# 93003               1020.21      Foggy in the morning.
# 93265               1016.30      Foggy in the morning.
# 93266               1016.41      Foggy in the morning.
# 93267               1016.60      Foggy in the morning.
# 93506               1014.76      Foggy in the morning.
#
# [2982 rows x 12 columns]

# %%
d[ ( d["Summary"]== "Foggy") | (d["Precip Type"] == "snow") ]
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 66     2006-04-11 18:00:00.000 +0200   Foggy        rain        10.911111
# 67     2006-04-11 19:00:00.000 +0200   Foggy        rain         8.800000
# 72     2006-04-12 00:00:00.000 +0200   Foggy        rain         8.200000
# 73     2006-04-12 01:00:00.000 +0200   Foggy        rain         8.177778
# 126    2006-04-14 06:00:00.000 +0200   Foggy        rain         5.211111
# ...                              ...     ...         ...              ...
# 95858  2016-09-14 05:00:00.000 +0200   Foggy        rain        13.144444
# 95859  2016-09-14 06:00:00.000 +0200   Foggy        rain        13.822222
# 95860  2016-09-14 07:00:00.000 +0200   Foggy        rain        13.872222
# 95907  2016-09-16 06:00:00.000 +0200   Foggy        rain        14.905556
# 96228  2016-09-28 15:00:00.000 +0200   Foggy        rain        22.800000
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 66                    10.911111      0.86            22.3951
# 67                     5.294444      0.99            26.5006
# 72                     5.072222      0.96            20.4470
# 73                     4.372222      0.93            27.8691
# 126                    5.211111      0.92             4.7656
# ...                         ...       ...                ...
# 95858                 13.144444      0.99             3.2039
# 95859                 13.822222      0.94             4.8300
# 95860                 13.872222      0.94             3.2039
# 95907                 14.905556      1.00             7.5992
# 96228                 22.800000      0.32            10.9158
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 66                      311.0           2.6565         0.0
# 67                      339.0           2.6565         0.0
# 72                      341.0           3.1073         0.0
# 73                       19.0           3.2039         0.0
# 126                     178.0           1.2236         0.0
# ...                       ...              ...         ...
# 95858                     2.0           2.2218         0.0
# 95859                    10.0           1.9642         0.0
# 95860                   321.0           1.9803         0.0
# 95907                   169.0           1.6100         0.0
# 96228                   231.0           0.7245         0.0
#
#        Pressure (millibars)                               Daily Summary
# 66                  1004.61                       Foggy in the evening.
# 67                  1004.99                       Foggy in the evening.
# 72                  1004.80  Foggy overnight and breezy in the morning.
# 73                  1004.89  Foggy overnight and breezy in the morning.
# 126                 1013.40           Mostly cloudy throughout the day.
# ...                     ...                                         ...
# 95858               1015.33                       Foggy in the morning.
# 95859               1015.44                       Foggy in the morning.
# 95860               1015.64                       Foggy in the morning.
# 95907               1016.51    Partly cloudy starting in the afternoon.
# 96228               1027.69    Partly cloudy starting in the afternoon.
#
# [14878 rows x 12 columns]

# %%
df2 = d[ (d["Humidity"] == "Foggy") & (d["Precip Type"] == "snow")]
df2
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
media_humedad = d['Humidity'].mean()
d.loc[d["Humidity"]<= media_humedad,["Humidity","Temperature (C)"] ]
# Out:
#        Humidity  Temperature (C)
# 9          0.72        13.772222
# 10         0.67        16.016667
# 11         0.54        17.144444
# 12         0.55        17.800000
# 13         0.51        17.333333
# ...         ...              ...
# 96448      0.43        26.016667
# 96449      0.48        24.583333
# 96450      0.56        22.038889
# 96451      0.60        21.522222
# 96452      0.61        20.438889
#
# [40336 rows x 2 columns]

# %%
d.loc[10:15,["Humidity","Temperature (C)"]]
# Out:
#     Humidity  Temperature (C)
# 10      0.67        16.016667
# 11      0.54        17.144444
# 12      0.55        17.800000
# 13      0.51        17.333333
# 14      0.47        18.877778
# 15      0.46        18.911111

# %%
d.loc[ d["Humidity"]<= media_humedad, :]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 9      2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain
# 10     2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain
# 11     2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain
# 12     2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain
# 13     2006-04-01 13:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 9            13.772222                 13.772222      0.72            12.5258
# 10           16.016667                 16.016667      0.67            17.5651
# 11           17.144444                 17.144444      0.54            19.7869
# 12           17.800000                 17.800000      0.55            21.9443
# 13           17.333333                 17.333333      0.51            20.6885
# ...                ...                       ...       ...                ...
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 9                       279.0           9.9820         0.0
# 10                      290.0          11.2056         0.0
# 11                      316.0          11.4471         0.0
# 12                      281.0          11.2700         0.0
# 13                      289.0          11.2700         0.0
# ...                       ...              ...         ...
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 9                   1017.22       Partly cloudy throughout the day.
# 10                  1017.42       Partly cloudy throughout the day.
# 11                  1017.74       Partly cloudy throughout the day.
# 12                  1017.59       Partly cloudy throughout the day.
# 13                  1017.48       Partly cloudy throughout the day.
# ...                     ...                                     ...
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.
#
# [40336 rows x 12 columns]

# %%
d.iloc[:,[0,2,1]]
# Out:
#                       Formatted Date Precip Type        Summary
# 0      2006-04-01 00:00:00.000 +0200        rain  Partly Cloudy
# 1      2006-04-01 01:00:00.000 +0200        rain  Partly Cloudy
# 2      2006-04-01 02:00:00.000 +0200        rain  Mostly Cloudy
# 3      2006-04-01 03:00:00.000 +0200        rain  Partly Cloudy
# 4      2006-04-01 04:00:00.000 +0200        rain  Mostly Cloudy
# ...                              ...         ...            ...
# 96448  2016-09-09 19:00:00.000 +0200        rain  Partly Cloudy
# 96449  2016-09-09 20:00:00.000 +0200        rain  Partly Cloudy
# 96450  2016-09-09 21:00:00.000 +0200        rain  Partly Cloudy
# 96451  2016-09-09 22:00:00.000 +0200        rain  Partly Cloudy
# 96452  2016-09-09 23:00:00.000 +0200        rain  Partly Cloudy
#
# [96453 rows x 3 columns]

# %%
d.iloc[:,[8,9]]
# Out:
#        Visibility (km)  Loud Cover
# 0              15.8263         0.0
# 1              15.8263         0.0
# 2              14.9569         0.0
# 3              15.8263         0.0
# 4              15.8263         0.0
# ...                ...         ...
# 96448          16.1000         0.0
# 96449          15.5526         0.0
# 96450          16.1000         0.0
# 96451          16.1000         0.0
# 96452          15.5204         0.0
#
# [96453 rows x 2 columns]

# %%
grouped_df = d.groupby("Summary")
print(type(grouped_df)) # Es un objeto
print(grouped_df)
# Mostremos el primer registro de cada uno
print(grouped_df.first())
print("Numero de grupos: ",len(grouped_df))

# veamos las caracteristicas y sus conincidencias
print(grouped_df.size())
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x2a0ca2b10>
#                                                     Formatted Date  \
# Summary
# Breezy                               2006-11-05 05:00:00.000 +0100
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2006-03-13 07:00:00.000 +0100
# Breezy and Mostly Cloudy             2006-04-12 08:00:00.000 +0200
# Breezy and Overcast                  2006-08-31 10:00:00.000 +0200
# Breezy and Partly Cloudy             2006-08-21 00:00:00.000 +0200
# Clear                                2006-04-18 07:00:00.000 +0200
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# Drizzle                              2012-04-12 10:00:00.000 +0200
# Dry                                  2007-07-20 10:00:00.000 +0200
# Dry and Mostly Cloudy                2012-08-31 14:00:00.000 +0200
# Dry and Partly Cloudy                2007-04-23 13:00:00.000 +0200
# Foggy                                2006-04-11 18:00:00.000 +0200
# Humid and Mostly Cloudy              2006-08-04 14:00:00.000 +0200
# Humid and Overcast                   2010-08-06 13:00:00.000 +0200
# Humid and Partly Cloudy              2006-07-02 15:00:00.000 +0200
# Light Rain                           2012-04-12 09:00:00.000 +0200
# Mostly Cloudy                        2006-04-01 02:00:00.000 +0200
# Overcast                             2006-04-10 22:00:00.000 +0200
# Partly Cloudy                        2006-04-01 00:00:00.000 +0200
# Rain                                 2016-10-21 23:00:00.000 +0200
# Windy                                2008-01-28 02:00:00.000 +0100
# Windy and Dry                        2012-04-29 12:00:00.000 +0200
# Windy and Foggy                      2006-07-08 18:00:00.000 +0200
# Windy and Mostly Cloudy              2007-02-01 13:00:00.000 +0100
# Windy and Overcast                   2006-03-12 23:00:00.000 +0100
# Windy and Partly Cloudy              2006-03-29 17:00:00.000 +0200
#
#                                     Precip Type  Temperature (C)  \
# Summary
# Breezy                                     rain         6.088889
# Breezy and Dry                             rain        21.111111
# Breezy and Foggy                           snow        -2.172222
# Breezy and Mostly Cloudy                   rain         6.144444
# Breezy and Overcast                        rain        15.944444
# Breezy and Partly Cloudy                   rain        21.966667
# Clear                                      rain         8.688889
# Dangerously Windy and Partly Cloudy        rain         8.944444
# Drizzle                                    rain        14.716667
# Dry                                        rain        34.055556
# Dry and Mostly Cloudy                      rain        33.672222
# Dry and Partly Cloudy                      rain        20.072222
# Foggy                                      rain        10.911111
# Humid and Mostly Cloudy                    rain        20.894444
# Humid and Overcast                         rain        24.055556
# Humid and Partly Cloudy                    rain        22.661111
# Light Rain                                 rain        12.011111
# Mostly Cloudy                              rain         9.377778
# Overcast                                   rain        14.422222
# Partly Cloudy                              rain         9.472222
# Rain                                       rain         9.738889
# Windy                                      rain         4.994444
# Windy and Dry                              rain        27.222222
# Windy and Foggy                            rain        19.633333
# Windy and Mostly Cloudy                    rain        10.050000
# Windy and Overcast                         rain         0.511111
# Windy and Partly Cloudy                    rain        12.100000
#
#                                      Apparent Temperature (C)  Humidity  \
# Summary
# Breezy                                               1.572222      0.76
# Breezy and Dry                                      21.111111      0.26
# Breezy and Foggy                                   -10.044444      0.90
# Breezy and Mostly Cloudy                             1.494444      0.93
# Breezy and Overcast                                 15.944444      0.68
# Breezy and Partly Cloudy                            21.966667      0.72
# Clear                                                8.688889      0.93
# Dangerously Windy and Partly Cloudy                  3.483333      0.49
# Drizzle                                             14.716667      0.59
# Dry                                                 33.005556      0.28
# Dry and Mostly Cloudy                               31.388889      0.17
# Dry and Partly Cloudy                               20.072222      0.17
# Foggy                                               10.911111      0.86
# Humid and Mostly Cloudy                             20.894444      0.82
# Humid and Overcast                                  24.055556      0.89
# Humid and Partly Cloudy                             22.661111      0.84
# Light Rain                                          12.011111      0.75
# Mostly Cloudy                                        9.377778      0.89
# Overcast                                            14.422222      0.58
# Partly Cloudy                                        7.388889      0.89
# Rain                                                 9.738889      0.96
# Windy                                               -0.866667      0.45
# Windy and Dry                                       26.344444      0.24
# Windy and Foggy                                     19.633333      0.76
# Windy and Mostly Cloudy                             10.050000      0.53
# Windy and Overcast                                  -7.116667      0.66
# Windy and Partly Cloudy                             12.100000      0.57
#
#                                      Wind Speed (km/h)  \
# Summary
# Breezy                                         29.0444
# Breezy and Dry                                 33.8100
# Breezy and Foggy                               37.4808
# Breezy and Mostly Cloudy                       30.8637
# Breezy and Overcast                            33.9066
# Breezy and Partly Cloudy                       30.8315
# Clear                                           1.4329
# Dangerously Windy and Partly Cloudy            63.8526
# Drizzle                                        24.7940
# Dry                                            13.8138
# Dry and Mostly Cloudy                          19.8352
# Dry and Partly Cloudy                           2.8014
# Foggy                                          22.3951
# Humid and Mostly Cloudy                         8.8711
# Humid and Overcast                             10.0786
# Humid and Partly Cloudy                        15.5204
# Light Rain                                     12.1716
# Mostly Cloudy                                   3.9284
# Overcast                                       20.0123
# Partly Cloudy                                  14.1197
# Rain                                            4.2826
# Windy                                          42.5362
# Windy and Dry                                  40.2500
# Windy and Foggy                                45.9333
# Windy and Mostly Cloudy                        47.2857
# Windy and Overcast                             45.5308
# Windy and Partly Cloudy                        41.6990
#
#                                      Wind Bearing (degrees)  Visibility (km)  \
# Summary
# Breezy                                                289.0           6.3434
# Breezy and Dry                                        240.0           9.9820
# Breezy and Foggy                                       18.0           1.4651
# Breezy and Mostly Cloudy                              349.0          10.5455
# Breezy and Overcast                                   289.0          11.2700
# Breezy and Partly Cloudy                              310.0          15.8263
# Clear                                                 290.0           5.8443
# Dangerously Windy and Partly Cloudy                   307.0          11.4471
# Drizzle                                               248.0          11.1090
# Dry                                                   179.0           9.9820
# Dry and Mostly Cloudy                                 149.0          10.3523
# Dry and Partly Cloudy                                 310.0           9.9820
# Foggy                                                 311.0           2.6565
# Humid and Mostly Cloudy                               342.0          11.3183
# Humid and Overcast                                    170.0           6.1663
# Humid and Partly Cloudy                                 1.0          11.1251
# Light Rain                                            230.0          11.1090
# Mostly Cloudy                                         204.0          14.9569
# Overcast                                              159.0          15.8263
# Partly Cloudy                                         251.0          15.8263
# Rain                                                  286.0           4.6529
# Windy                                                 340.0          15.8263
# Windy and Dry                                         150.0           9.9820
# Windy and Foggy                                        90.0           2.3506
# Windy and Mostly Cloudy                               308.0          11.0768
# Windy and Overcast                                     20.0          11.9784
# Windy and Partly Cloudy                               279.0          11.4471
#
#                                      Loud Cover  Pressure (millibars)  \
# Summary
# Breezy                                      0.0               1021.45
# Breezy and Dry                              0.0               1021.60
# Breezy and Foggy                            0.0               1014.15
# Breezy and Mostly Cloudy                    0.0               1004.10
# Breezy and Overcast                         0.0               1016.52
# Breezy and Partly Cloudy                    0.0               1015.64
# Clear                                       0.0               1012.96
# Dangerously Windy and Partly Cloudy         0.0               1009.05
# Drizzle                                     0.0               1002.78
# Dry                                         0.0               1014.03
# Dry and Mostly Cloudy                       0.0               1011.83
# Dry and Partly Cloudy                       0.0               1025.13
# Foggy                                       0.0               1004.61
# Humid and Mostly Cloudy                     0.0               1005.05
# Humid and Overcast                          0.0               1008.56
# Humid and Partly Cloudy                     0.0               1017.99
# Light Rain                                  0.0               1002.70
# Mostly Cloudy                               0.0               1015.94
# Overcast                                    0.0               1007.85
# Partly Cloudy                               0.0               1015.13
# Rain                                        0.0               1014.10
# Windy                                       0.0               1019.01
# Windy and Dry                               0.0               1020.20
# Windy and Foggy                             0.0               1014.92
# Windy and Mostly Cloudy                     0.0               1015.30
# Windy and Overcast                          0.0               1012.71
# Windy and Partly Cloudy                     0.0               1008.47
#
#                                                                          Daily Summary
# Summary
# Breezy                                      Overcast until night and breezy overnight.
# Breezy and Dry                                Partly cloudy starting in the afternoon.
# Breezy and Foggy                     Breezy starting overnight continuing until aft...
# Breezy and Mostly Cloudy                    Foggy overnight and breezy in the morning.
# Breezy and Overcast                  Mostly cloudy until night and breezy in the af...
# Breezy and Partly Cloudy                             Mostly cloudy starting overnight.
# Clear                                                       Partly cloudy until night.
# Dangerously Windy and Partly Cloudy  Mostly cloudy throughout the day and windy sta...
# Drizzle                                                     Light rain in the morning.
# Dry                                  Partly cloudy starting in the afternoon contin...
# Dry and Mostly Cloudy                                Partly cloudy throughout the day.
# Dry and Partly Cloudy                Partly cloudy starting in the morning continui...
# Foggy                                                            Foggy in the evening.
# Humid and Mostly Cloudy                                     Mostly cloudy until night.
# Humid and Overcast                                   Partly cloudy throughout the day.
# Humid and Partly Cloudy                              Mostly cloudy throughout the day.
# Light Rain                                                  Light rain in the morning.
# Mostly Cloudy                                        Partly cloudy throughout the day.
# Overcast                                             Mostly cloudy throughout the day.
# Partly Cloudy                                        Partly cloudy throughout the day.
# Rain                                                          Rain throughout the day.
# Windy                                Breezy starting overnight continuing until mor...
# Windy and Dry                        Partly cloudy starting in the morning continui...
# Windy and Foggy                      Partly cloudy starting in the afternoon contin...
# Windy and Mostly Cloudy              Partly cloudy starting overnight continuing un...
# Windy and Overcast                   Foggy in the morning and breezy starting in th...
# Windy and Partly Cloudy              Partly cloudy throughout the day and breezy st...
# Numero de grupos:  27
# Summary
# Breezy                                    54
# Breezy and Dry                             1
# Breezy and Foggy                          35
# Breezy and Mostly Cloudy                 516
# Breezy and Overcast                      528
# Breezy and Partly Cloudy                 386
# Clear                                  10890
# Dangerously Windy and Partly Cloudy        1
# Drizzle                                   39
# Dry                                       34
# Dry and Mostly Cloudy                     14
# Dry and Partly Cloudy                     86
# Foggy                                   7148
# Humid and Mostly Cloudy                   40
# Humid and Overcast                         7
# Humid and Partly Cloudy                   17
# Light Rain                                63
# Mostly Cloudy                          28094
# Overcast                               16597
# Partly Cloudy                          31733
# Rain                                      10
# Windy                                      8
# Windy and Dry                              1
# Windy and Foggy                            4
# Windy and Mostly Cloudy                   35
# Windy and Overcast                        45
# Windy and Partly Cloudy                   67
# dtype: int64

# %%
grouped_df.get_group("Light Rain")["Humidity"].mean()
# Out:
# 0.888095238095238

# %%
df_ordenado = d.sort_values(by=["Temperature (C)"],ascending=False)
df_final = df_ordenado.iloc[0:100,0:5] #    primeras 100 filas y primeras 5 columnas


media_humedad = d["Humidity"].mean()

condicion = (df_ordenado["Humidity"] <= media_humedad) & (df_ordenado["Summary"].str.contains("cloudy",case=False))
df_final  = df_ordenado.loc[condicion,:]
df_final = df_final.reset_index(drop=True)
print(df_final)
df_final = df_final.iloc[0:100,[1,5,9,2]]
df_final
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2007-07-21 17:00:00.000 +0200  Partly Cloudy        rain
# 1      2007-07-19 16:00:00.000 +0200  Partly Cloudy        rain
# 2      2007-07-20 16:00:00.000 +0200  Partly Cloudy        rain
# 3      2007-07-20 15:00:00.000 +0200  Partly Cloudy        rain
# 4      2007-07-21 15:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 32630  2012-02-02 08:00:00.000 +0100  Mostly Cloudy        snow
# 32631  2012-02-02 05:00:00.000 +0100  Partly Cloudy        snow
# 32632  2012-02-02 06:00:00.000 +0100  Partly Cloudy        snow
# 32633  2009-12-21 07:00:00.000 +0100  Partly Cloudy        snow
# 32634  2012-02-09 20:00:00.000 +0100  Partly Cloudy        snow
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            39.588889                 37.600000      0.15            12.2038
# 1            38.983333                 37.461111      0.18             8.9355
# 2            38.983333                 36.800000      0.15            15.4077
# 3            38.983333                 36.627778      0.14            12.7190
# 4            38.866667                 37.950000      0.21            12.7512
# ...                ...                       ...       ...                ...
# 32630       -12.777778                -19.011111      0.00            11.2700
# 32631       -12.777778                -20.005556      0.69            14.4900
# 32632       -12.777778                -19.011111      0.00            11.2700
# 32633       -14.772222                -24.233333      0.73            21.7511
# 32634       -16.111111                -21.661111      0.00             8.0500
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                       283.0          10.3523         0.0
# 1                       175.0           9.9820         0.0
# 2                       133.0           9.9820         0.0
# 3                       167.0           9.9820         0.0
# 4                       269.0           9.9820         0.0
# ...                       ...              ...         ...
# 32630                    20.0           9.9820         0.0
# 32631                    20.0           9.9820         0.0
# 32632                    20.0           9.9820         0.0
# 32633                   151.0           7.9856         0.0
# 32634                   180.0           4.0250         0.0
#
#        Pressure (millibars)                                      Daily Summary
# 0                   1010.24  Partly cloudy starting in the morning continui...
# 1                   1013.34           Partly cloudy starting in the afternoon.
# 2                   1011.93  Partly cloudy starting in the afternoon contin...
# 3                   1012.34  Partly cloudy starting in the afternoon contin...
# 4                   1011.00  Partly cloudy starting in the morning continui...
# ...                     ...                                                ...
# 32630               1028.10                  Mostly cloudy throughout the day.
# 32631               1027.40                  Mostly cloudy throughout the day.
# 32632               1027.60                  Mostly cloudy throughout the day.
# 32633               1017.25             Mostly cloudy starting in the morning.
# 32634               1029.40                               Foggy until morning.
#
# [32635 rows x 12 columns]
#           Summary  Humidity  Loud Cover Precip Type
# 0   Partly Cloudy      0.15         0.0        rain
# 1   Partly Cloudy      0.18         0.0        rain
# 2   Partly Cloudy      0.15         0.0        rain
# 3   Partly Cloudy      0.14         0.0        rain
# 4   Partly Cloudy      0.21         0.0        rain
# ..            ...       ...         ...         ...
# 95  Partly Cloudy      0.27         0.0        rain
# 96  Partly Cloudy      0.30         0.0        rain
# 97  Partly Cloudy      0.24         0.0        rain
# 98  Partly Cloudy      0.31         0.0        rain
# 99  Partly Cloudy      0.19         0.0        rain
#
# [100 rows x 4 columns]
